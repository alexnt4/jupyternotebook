# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Alex García Castañeda
#
# 100% Human

# %% [markdown]
# I love data science because I'm so curious

# %%
The following code test the Gauss formula

# %%
def gauss(n):
    return (n*(n+1))/2

gauss(100) == sum(range(101))
# Out:
# True

# %% [markdown]
# ![180px-Coat_of_arms_of_Berlin.svg.png](attachment:c6ba4542-e3ce-466c-83d5-da263b81ed9f.png)
#
# <p>This is some info.</p>
# <p>    1. This is question one.</p>
# <p>This is more info.</p>
# <p>    2. This is question two.</p>
#
#
# <a href="https://jupyter.org/">Jupyter Notebook </a>
