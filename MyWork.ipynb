# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# **Alex García Castañeda**
#
# 100% Data

# %% [markdown]
# *I love data science because I'm so curious*

# %% [markdown]
# <h3>The following code Evaluate an fx expression with Sympy</h3>

# %%
k = fx.subs(x,0.1)
print(k)
# Out:
# 0.518540000000000

# %% [markdown]
# ![l.png](attachment:l.png)
#
# <a href="https://jupyter.org/">Jupyter Notebook</a>
#
# <p>This is a image generate by a ia.</p>
# <p>    1. Is a cyberpunk style.</p>
# <p>This is more info.</p>
# <p>    2. OpenIa.</p>
